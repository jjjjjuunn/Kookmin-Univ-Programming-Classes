# %% [markdown]
# # 📚 중간고사 범위 (Week 2-7)
# ## 주제: 스택(Stack) 구현 - 연결 리스트 응용

# %% [markdown]
# # 스택 구현: 단순 연결 리스트
# - 연결 자료구조를 이용하여 스택 구조를 구현하세요.

# %%
class LinkedStack:
    class SNode:
        def __init__(self, data, link = None):
            self.data = data
            self.link = link
        def __del__(self):
            pass
        def empty(self) -> bool:
            pass
        def size(self) -> int:
            pass
        def push(self) -> None:
            pass
        def pop(self) -> None:
            pass
        def top(self):
            pass
        def printStack(self)-> None:
            pass
    def __init__(self):
        self.__top = None
        self.__count = 0

if __name__ == '__main__':
    StackList = LinkedStack()

    print('### 스택 구현: 단순연결리스트 ###')
    print('1) 데이터 삽입: push')
    print('2) 데이터 삭제 : pop')
    print('3) 전체 출력')
    print('4) 프로그램 종료\n')
    menu_num = int(input('메뉴 선택: '))

    match(menu_num):

        case '1':
            StackList.push()
        case '2':
            StackList.pop()
        case '3':
            StackList.printStack()
        case '4':
            exit(1)
